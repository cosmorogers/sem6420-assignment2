# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/train_parkinsons.csv')

# %%
df.head(10)
# Out:
#    MDVP_Fo  MDVP_Fhi  MDVP_Flo  MDVP_Jitter_pct  MDVP_Jitter_abs  MDVP_RAP  \
# 0  228.832   470.446   223.634          0.00296         0.000010   0.00175
# 1  183.520   186.101   161.340          0.01466         0.000080   0.00849
# 2  153.880   310.467    78.128          0.00480         0.000030   0.00232
# 3  119.056   159.834    86.795          0.00346         0.000030   0.00169
# 4  125.791   533.860    96.206          0.01378         0.000110   0.00826
# 5  136.926   440.862   131.276          0.00293         0.000020   0.00118
# 6  116.150   290.040   109.815          0.00381         0.000030   0.00181
# 7  193.030   241.775    80.297          0.00766         0.000040   0.00450
# 8  186.163   358.682   177.584          0.00298         0.000020   0.00165
# 9  252.455   397.243   182.786          0.00185         0.000007   0.00092
#
#    MDVP_PPQ  Jitter_DDP  MDVP_Shimmer  MDVP_Shimmer_db   ...    Shimmer_DDA  \
# 0   0.00155     0.00526       0.01644            0.145   ...        0.02647
# 1   0.00819     0.02546       0.06050            0.618   ...        0.08595
# 2   0.00267     0.00696       0.04137            0.370   ...        0.06062
# 3   0.00170     0.00508       0.01201            0.106   ...        0.01898
# 4   0.00655     0.02478       0.04689            0.422   ...        0.07625
# 5   0.00153     0.00355       0.01259            0.112   ...        0.01968
# 6   0.00232     0.00542       0.03026            0.267   ...        0.04543
# 7   0.00389     0.01351       0.03044            0.275   ...        0.05312
# 8   0.00175     0.00496       0.01495            0.135   ...        0.02321
# 9   0.00113     0.00276       0.01152            0.103   ...        0.01841
#
#        NHR     HNR      RPDE       DFA   spread1   spread2        D2  \
# 0  0.00351  25.964  0.256570  0.683296 -7.245620  0.018689  2.498224
# 1  0.06057  14.367  0.478024  0.768974 -4.276605  0.355736  3.142364
# 2  0.01849  19.493  0.629017  0.698951 -5.186960  0.237622  2.557536
# 3  0.00903  23.389  0.470972  0.721308 -5.436135  0.254909  2.516320
# 4  0.10323  15.433  0.571010  0.690892 -5.159169  0.202146  2.441612
# 5  0.00581  25.703  0.460600  0.646846 -6.547148  0.152813  2.041277
# 6  0.01827  18.801  0.624811  0.696049 -5.866357  0.233070  2.445646
# 7  0.00947  21.934  0.497554  0.740539 -5.845099  0.278679  2.608749
# 8  0.00231  26.822  0.326480  0.765623 -6.647379  0.201095  2.374073
# 9  0.00432  26.805  0.610367  0.635204 -7.319510  0.200873  2.028612
#
#         PPE  status
# 0  0.298110       0
# 1  0.280750       1
# 2  0.407439       1
# 3  0.187366       1
# 4  0.227876       1
# 5  0.123422       1
# 6  0.172303       1
# 7  0.323240       1
# 8  0.179574       1
# 9  0.105572       0
#
# [10 rows x 23 columns]

# %%
df = df.drop(['MDVP_Jitter_pct', 'MDVP_RAP', 'MDVP_RAP', 'MDVP_Shimmer', 'MDVP_Shimmer_db', 'Shimmer_APQ3',	'Shimmer_APQ5'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 0 to 174
# Data columns (total 17 columns):
# MDVP_Fo            175 non-null float64
# MDVP_Fhi           175 non-null float64
# MDVP_Flo           175 non-null float64
# MDVP_Jitter_abs    175 non-null float64
# MDVP_PPQ           175 non-null float64
# Jitter_DDP         175 non-null float64
# MDVP_APQ           175 non-null float64
# Shimmer_DDA        175 non-null float64
# NHR                175 non-null float64
# HNR                175 non-null float64
# RPDE               175 non-null float64
# DFA                175 non-null float64
# spread1            175 non-null float64
# spread2            175 non-null float64
# D2                 175 non-null float64
# PPE                175 non-null float64
# status             175 non-null int64
# dtypes: float64(16), int64(1)
# memory usage: 24.6 KB

# %%
cols = df.columns.tolist()
print(cols)
# Out:
# ['MDVP_Fo', 'MDVP_Fhi', 'MDVP_Flo', 'MDVP_Jitter_abs', 'MDVP_PPQ', 'Jitter_DDP', 'MDVP_APQ', 'Shimmer_DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE', 'status']

# %%
df.head(10)
# Out:
#    MDVP_Fo  MDVP_Fhi  MDVP_Flo  MDVP_Jitter_abs  MDVP_PPQ  Jitter_DDP  \
# 0  228.832   470.446   223.634         0.000010   0.00155     0.00526
# 1  183.520   186.101   161.340         0.000080   0.00819     0.02546
# 2  153.880   310.467    78.128         0.000030   0.00267     0.00696
# 3  119.056   159.834    86.795         0.000030   0.00170     0.00508
# 4  125.791   533.860    96.206         0.000110   0.00655     0.02478
# 5  136.926   440.862   131.276         0.000020   0.00153     0.00355
# 6  116.150   290.040   109.815         0.000030   0.00232     0.00542
# 7  193.030   241.775    80.297         0.000040   0.00389     0.01351
# 8  186.163   358.682   177.584         0.000020   0.00175     0.00496
# 9  252.455   397.243   182.786         0.000007   0.00113     0.00276
#
#    MDVP_APQ  Shimmer_DDA      NHR     HNR      RPDE       DFA   spread1  \
# 0   0.01179      0.02647  0.00351  25.964  0.256570  0.683296 -7.245620
# 1   0.06359      0.08595  0.06057  14.367  0.478024  0.768974 -4.276605
# 2   0.04525      0.06062  0.01849  19.493  0.629017  0.698951 -5.186960
# 3   0.00915      0.01898  0.00903  23.389  0.470972  0.721308 -5.436135
# 4   0.03908      0.07625  0.10323  15.433  0.571010  0.690892 -5.159169
# 5   0.01140      0.01968  0.00581  25.703  0.460600  0.646846 -6.547148
# 6   0.02770      0.04543  0.01827  18.801  0.624811  0.696049 -5.866357
# 7   0.02084      0.05312  0.00947  21.934  0.497554  0.740539 -5.845099
# 8   0.01233      0.02321  0.00231  26.822  0.326480  0.765623 -6.647379
# 9   0.00860      0.01841  0.00432  26.805  0.610367  0.635204 -7.319510
#
#     spread2        D2       PPE  status
# 0  0.018689  2.498224  0.298110       0
# 1  0.355736  3.142364  0.280750       1
# 2  0.237622  2.557536  0.407439       1
# 3  0.254909  2.516320  0.187366       1
# 4  0.202146  2.441612  0.227876       1
# 5  0.152813  2.041277  0.123422       1
# 6  0.233070  2.445646  0.172303       1
# 7  0.278679  2.608749  0.323240       1
# 8  0.201095  2.374073  0.179574       1
# 9  0.200873  2.028612  0.105572       0

# %%
cols = df.columns.tolist()
cols = [cols[16]] + cols[1:16]
df = df[cols]

df.head(10)
# Out:
#    status  MDVP_Fhi  MDVP_Flo  MDVP_Jitter_abs  MDVP_PPQ  Jitter_DDP  \
# 0       0   470.446   223.634         0.000010   0.00155     0.00526
# 1       1   186.101   161.340         0.000080   0.00819     0.02546
# 2       1   310.467    78.128         0.000030   0.00267     0.00696
# 3       1   159.834    86.795         0.000030   0.00170     0.00508
# 4       1   533.860    96.206         0.000110   0.00655     0.02478
# 5       1   440.862   131.276         0.000020   0.00153     0.00355
# 6       1   290.040   109.815         0.000030   0.00232     0.00542
# 7       1   241.775    80.297         0.000040   0.00389     0.01351
# 8       1   358.682   177.584         0.000020   0.00175     0.00496
# 9       0   397.243   182.786         0.000007   0.00113     0.00276
#
#    MDVP_APQ  Shimmer_DDA      NHR     HNR      RPDE       DFA   spread1  \
# 0   0.01179      0.02647  0.00351  25.964  0.256570  0.683296 -7.245620
# 1   0.06359      0.08595  0.06057  14.367  0.478024  0.768974 -4.276605
# 2   0.04525      0.06062  0.01849  19.493  0.629017  0.698951 -5.186960
# 3   0.00915      0.01898  0.00903  23.389  0.470972  0.721308 -5.436135
# 4   0.03908      0.07625  0.10323  15.433  0.571010  0.690892 -5.159169
# 5   0.01140      0.01968  0.00581  25.703  0.460600  0.646846 -6.547148
# 6   0.02770      0.04543  0.01827  18.801  0.624811  0.696049 -5.866357
# 7   0.02084      0.05312  0.00947  21.934  0.497554  0.740539 -5.845099
# 8   0.01233      0.02321  0.00231  26.822  0.326480  0.765623 -6.647379
# 9   0.00860      0.01841  0.00432  26.805  0.610367  0.635204 -7.319510
#
#     spread2        D2       PPE
# 0  0.018689  2.498224  0.298110
# 1  0.355736  3.142364  0.280750
# 2  0.237622  2.557536  0.407439
# 3  0.254909  2.516320  0.187366
# 4  0.202146  2.441612  0.227876
# 5  0.152813  2.041277  0.123422
# 6  0.233070  2.445646  0.172303
# 7  0.278679  2.608749  0.323240
# 8  0.201095  2.374073  0.179574
# 9  0.200873  2.028612  0.105572

# %%
df.describe()
# Out:
#            status    MDVP_Fhi    MDVP_Flo  MDVP_Jitter_abs    MDVP_PPQ  \
# count  175.000000  175.000000  175.000000       175.000000  175.000000
# mean     0.777143  344.372337  114.385377         0.000044    0.003435
# std      0.417357  111.509984   42.379633         0.000035    0.002605
# min      0.000000    5.952000   65.476000         0.000007    0.000920
# 25%      1.000000  269.309500   83.650500         0.000020    0.001850
# 50%      1.000000  357.547000  102.874000         0.000030    0.002750
# 75%      1.000000  424.025000  132.066500         0.000060    0.003985
# max      1.000000  592.030000  239.170000         0.000260    0.016990
#
#        Jitter_DDP    MDVP_APQ  Shimmer_DDA         NHR         HNR  \
# count  175.000000  175.000000   175.000000  175.000000  175.000000
# mean     0.009902    0.024057     0.047177    0.024057   21.923469
# std      0.008660    0.015305     0.029974    0.039154    4.317966
# min      0.002040    0.007260     0.013640    0.000650    8.867000
# 25%      0.004960    0.013080     0.024875    0.006080   19.505000
# 50%      0.007500    0.018520     0.038520    0.011610   22.085000
# 75%      0.011625    0.029600     0.060795    0.025420   25.155000
# max      0.064330    0.088080     0.166540    0.314820   33.047000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  175.000000  175.000000  175.000000  175.000000  175.000000  175.000000
# mean     0.499502    0.719579   -5.657764    0.228009    2.381212    0.220841
# std      0.102674    0.055967    1.058972    0.081757    0.385105    0.099851
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.026532
# 25%      0.427706    0.676044   -6.443766    0.178132    2.092837    0.139417
# 50%      0.497554    0.722356   -5.657899    0.221711    2.344876    0.227876
# 75%      0.583869    0.762843   -4.986057    0.279234    2.636456    0.275002
# max      0.685151    0.825288   -2.839756    0.434326    3.671155    0.527367

# %%
# %matplotlib inline: To make matplotlib inline graphics
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
# Histograms for checking the distributions of the variables.
df.status.value_counts().plot(kind='bar')

# %%
scale        = lambda x: (x - x.mean()) / x.std()
from sklearn.decomposition import PCA

# use .iloc to get subset of DataFrame
df_std = df.iloc[0:,2:].apply(scale)

pca   = PCA(n_components = 4).fit(df_std)
vr = pca.explained_variance_ratio_
print("Variance exlained : %0.3f, %0.3f, %0.3f, %0.3f" % (vr[0], vr[1], vr[2], vr[3]))
print("Total variance explained with the first 4 PCs: %0.3f" % (sum(vr)))
print(pca.components_)


Xtrans = pca.transform(df_std)
dfx = pd.DataFrame(Xtrans, columns=['PC1', 'PC2', 'PC3', 'PC4'])
# Out:
# Variance exlained : 0.527, 0.109, 0.098, 0.072
# Total variance explained with the first 4 PCs: 0.806
# [[ 0.1056694  -0.32224214 -0.33391659 -0.32665268 -0.32273732 -0.31585568
#   -0.30859005  0.32352508 -0.21087178 -0.04078771 -0.30881512 -0.20457198
#   -0.21505901 -0.18268504]
#  [-0.5393578  -0.09502577 -0.18903436 -0.28120222 -0.04061264 -0.11522954
#   -0.31355173  0.05190408  0.3092313   0.24915567  0.28147041  0.40637966
#   -0.00526143  0.25926509]
#  [-0.03508557 -0.22514245 -0.21052257 -0.12346054  0.02966651 -0.02736826
#    0.0689752  -0.15919988  0.30244175 -0.6702765  -0.03845135  0.18156955
#    0.447311   -0.28550233]
#  [ 0.49409639 -0.25846612 -0.01855867 -0.15194149  0.23086804  0.10769616
#   -0.2091296  -0.07689796 -0.28904485  0.36523716  0.00700808  0.39774692
#    0.41849113 -0.0274721 ]]

# %%
plt.figure()
ax=dfx[df['status']==1].plot(kind='scatter', x='PC1', y='PC2', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC1', y='PC2', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

ax=dfx[df['status']==1].plot(kind='scatter', x='PC1', y='PC3', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC1', y='PC3', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

ax=dfx[df['status']==1].plot(kind='scatter', x='PC2', y='PC3', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC2', y='PC3', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

# %%
from sklearn.cross_validation import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.metrics import roc_curve, auc

train_data = df.values
X = train_data[:, 2:]
y = train_data[:, 0]

n = len(df)/2

cv = KFold(n=len(train_data), n_folds=5)


mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = RandomForestClassifier(n_estimators=100)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Random Forest (Dataset A)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.971428571429
# Area under ROC curve (AUC): 0.990740740741
# Prediction accuracy:
#  0.885714285714
# Area under ROC curve (AUC): 0.927419354839
# Prediction accuracy:
#  0.914285714286
# Area under ROC curve (AUC): 0.979020979021
# Prediction accuracy:
#  0.885714285714
# Area under ROC curve (AUC): 0.925925925926
# Prediction accuracy:
#  0.857142857143
# Area under ROC curve (AUC): 0.876436781609
# [ 0.97142857  0.88571429  0.91428571  0.88571429  0.85714286]
# Mean Accuracy: 0.903 (+/- 0.076)
# [ 0.99074074  0.92741935  0.97902098  0.92592593  0.87643678]
# Mean AUC: 0.940 (+/- 0.081)

# %%
mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = svm.SVC(probability=True)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC SVM (Dataset A)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.828571428571
# Area under ROC curve (AUC): 0.828703703704
# Prediction accuracy: 0.942857142857
# Area under ROC curve (AUC): 0.806451612903
# Prediction accuracy:
#  0.657142857143
# Area under ROC curve (AUC): 0.853146853147
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.884259259259
# Prediction accuracy: 0.828571428571
# Area under ROC curve (AUC): 0.925287356322
# [ 0.82857143  0.94285714  0.65714286  0.85714286  0.82857143]
# Mean Accuracy: 0.823 (+/- 0.182)
# [ 0.8287037   0.80645161  0.85314685  0.88425926  0.92528736]
# Mean AUC: 0.860 (+/- 0.082)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

rng = np.random.RandomState(1)

mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=4),
                          n_estimators=300, random_state=rng)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    i = i+1
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC AdaBoost Decision Tree (Dataset A)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.942857142857
# Area under ROC curve (AUC): 0.986111111111
# Prediction accuracy:
#  0.914285714286
# Area under ROC curve (AUC): 0.967741935484
# Prediction accuracy:
#  0.857142857143
# Area under ROC curve (AUC): 0.965034965035
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.863425925926
# Prediction accuracy: 0.8
# Area under ROC curve (AUC): 0.879310344828
# [ 0.94285714  0.91428571  0.85714286  0.85714286  0.8       ]
# Mean Accuracy: 0.874 (+/- 0.098)
# [ 0.98611111  0.96774194  0.96503497  0.86342593  0.87931034]
# Mean AUC: 0.932 (+/- 0.099)

# %%
mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = DecisionTreeClassifier(max_depth=4)
    
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    i = i+1
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Decision Tree (Dataset A)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.885714285714
# Area under ROC curve (AUC): 0.87037037037
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.806451612903
# Prediction accuracy: 0.714285714286
# Area under ROC curve (AUC): 0.618881118881
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.8125
# Prediction accuracy:
#  0.771428571429
# Area under ROC curve (AUC): 0.597701149425
# [ 0.88571429  0.85714286  0.71428571  0.85714286  0.77142857]
# Mean Accuracy: 0.817 (+/- 0.126)
# [ 0.87037037  0.80645161  0.61888112  0.8125      0.59770115]
# Mean AUC: 0.741 (+/- 0.218)
