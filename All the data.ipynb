# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/train_parkinsons.csv')

cols = df.columns.tolist()
print cols
cols = [cols[22]] + cols[0:22]
df = df[cols]

print(df.columns.tolist())
# Out:
# ['MDVP_Fo', 'MDVP_Fhi', 'MDVP_Flo', 'MDVP_Jitter_pct', 'MDVP_Jitter_abs', 'MDVP_RAP', 'MDVP_PPQ', 'Jitter_DDP', 'MDVP_Shimmer', 'MDVP_Shimmer_db', 'Shimmer_APQ3', 'Shimmer_APQ5', 'MDVP_APQ', 'Shimmer_DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE', 'status']
# ['status', 'MDVP_Fo', 'MDVP_Fhi', 'MDVP_Flo', 'MDVP_Jitter_pct', 'MDVP_Jitter_abs', 'MDVP_RAP', 'MDVP_PPQ', 'Jitter_DDP', 'MDVP_Shimmer', 'MDVP_Shimmer_db', 'Shimmer_APQ3', 'Shimmer_APQ5', 'MDVP_APQ', 'Shimmer_DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE']

# %%
# %matplotlib inline: To make matplotlib inline graphics
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
scale        = lambda x: (x - x.mean()) / x.std()
from sklearn.decomposition import PCA

# use .iloc to get subset of DataFrame
df_std = df.iloc[0:,2:].apply(scale)

pca   = PCA(n_components = 4).fit(df_std)
vr = pca.explained_variance_ratio_
print("Variance exlained : %0.3f, %0.3f, %0.3f, %0.3f" % (vr[0], vr[1], vr[2], vr[3]))
print("Total variance explained with the first 4 PCs: %0.3f" % (sum(vr)))
print(pca.components_)


Xtrans = pca.transform(df_std)
dfx = pd.DataFrame(Xtrans, columns=['PC1', 'PC2', 'PC3', 'PC4'])
# Out:
# Variance exlained : 0.586, 0.082, 0.071, 0.066
# Total variance explained with the first 4 PCs: 0.805
# [[-0.0220209   0.06373755 -0.26062957 -0.24604361 -0.25563886 -0.26146339
#   -0.25562794 -0.26718015 -0.26866039 -0.26108518 -0.25745275 -0.25983554
#   -0.26108741 -0.23999688  0.25081179 -0.14555653 -0.03596773 -0.2223631
#   -0.14027631 -0.15810989 -0.13087499]
#  [ 0.00517292 -0.44056902 -0.21261369 -0.13724798 -0.2659407  -0.18126564
#   -0.26602807  0.03468166  0.00133213  0.00467764  0.06155268  0.08841064
#    0.0046688  -0.24834355 -0.08229904  0.36193171  0.11688078  0.27365867
#    0.44825518  0.16652417  0.19485668]
#  [-0.20015146  0.358067   -0.207106   -0.32386494 -0.19455125 -0.14546192
#   -0.19457349  0.24278618  0.22958676  0.24498261  0.29195324  0.23419645
#    0.24495995 -0.14707903 -0.11928578 -0.1549442   0.02736202 -0.24599491
#   -0.03343836  0.17214742 -0.25185712]
#  [-0.12805393 -0.00885806  0.00986243  0.09067692 -0.02317388  0.10827978
#   -0.02317783  0.04604836  0.05540701  0.04948366  0.10212978  0.01826764
#    0.04949823 -0.21358532  0.14782068 -0.26952666  0.76021496  0.0462931
#   -0.0550781  -0.38293926  0.2677535 ]]

# %%
plt.figure()
ax=dfx[df['status']==1].plot(kind='scatter', x='PC1', y='PC2', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC1', y='PC2', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

ax=dfx[df['status']==1].plot(kind='scatter', x='PC1', y='PC3', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC1', y='PC3', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

ax=dfx[df['status']==1].plot(kind='scatter', x='PC2', y='PC3', color='red', label='Parkinson')
dfx[df['status']==0].plot(kind='scatter', x='PC2', y='PC3', color='green', label='Healthy ',ax=ax)
plt.title('PCA of Parkinson training dataset')

# %%
from sklearn.cross_validation import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.metrics import roc_curve, auc

train_data = df.values


X = train_data[:, 2:]
y = train_data[:, 0]

n = len(df)/2

cv = KFold(n=len(train_data), n_folds=5)

# %%
mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = RandomForestClassifier(n_estimators=100)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Random Forest (Dataset C)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.914285714286
# Area under ROC curve (AUC): 0.979166666667
# Prediction accuracy:
#  0.914285714286
# Area under ROC curve (AUC): 0.903225806452
# Prediction accuracy:
#  0.914285714286
# Area under ROC curve (AUC): 0.956293706294
# Prediction accuracy:
#  0.885714285714
# Area under ROC curve (AUC): 0.930555555556
# Prediction accuracy:
#  0.885714285714
# Area under ROC curve (AUC): 0.807471264368
# [ 0.91428571  0.91428571  0.91428571  0.88571429  0.88571429]
# Mean Accuracy: 0.903 (+/- 0.027)
# [ 0.97916667  0.90322581  0.95629371  0.93055556  0.80747126]
# Mean AUC: 0.915 (+/- 0.117)

# %%
mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = svm.SVC(probability=True)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC SVM (Dataset C)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.771428571429
# Area under ROC curve (AUC): 0.328703703704
# Prediction accuracy: 0.885714285714
# Area under ROC curve (AUC):
#  0.225806451613
# Prediction accuracy: 0.628571428571
# Area under ROC curve (AUC): 0.43006993007
# Prediction accuracy: 0.771428571429
# Area under ROC curve (AUC): 0.560185185185
# Prediction accuracy: 0.828571428571
# Area under ROC curve (AUC): 0.528735632184
# [ 0.77142857  0.88571429  0.62857143  0.77142857  0.82857143]
# Mean Accuracy: 0.777 (+/- 0.168)
# [ 0.3287037   0.22580645  0.43006993  0.56018519  0.52873563]
# Mean AUC: 0.415 (+/- 0.244)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

rng = np.random.RandomState(1)

mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = AdaBoostClassifier(DecisionTreeClassifier(max_depth=4),
                          n_estimators=300, random_state=rng)
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    i = i+1
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC AdaBoost Decision Tree (Dataset C)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.885714285714
# Area under ROC curve (AUC): 0.976851851852
# Prediction accuracy:
#  0.885714285714
# Area under ROC curve (AUC): 0.967741935484
# Prediction accuracy:
#  0.8
# Area under ROC curve (AUC): 0.916083916084
# Prediction accuracy: 0.828571428571
# Area under ROC curve (AUC): 0.847222222222
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.879310344828
# [ 0.88571429  0.88571429  0.8         0.82857143  0.85714286]
# Mean Accuracy: 0.851 (+/- 0.065)
# [ 0.97685185  0.96774194  0.91608392  0.84722222  0.87931034]
# Mean AUC: 0.917 (+/- 0.098)

# %%
mean_acc = 0.0
mean_auc = 0.0
all_tpr = []
all_acc = []
all_auc = []
i=0

plt.figure(figsize=(8,8))


for training_set, test_set in cv:
    X_train = X[training_set]
    y_train = y[training_set]
    X_test = X[test_set]
    y_test = y[test_set]
    model = DecisionTreeClassifier(max_depth=4)
    
    model.fit(X_train, y_train)
    y_prediction = model.predict(X_test)    
    
    # Get probability output from the model
    y_prob = model.predict_proba(X_test)
    acc = np.sum(y_test == y_prediction)*1./len(y_test)
    print "Prediction accuracy:", acc
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y_test, y_prob[:, 1])
    roc_auc = auc(fpr, tpr)
    print "Area under ROC curve (AUC):", roc_auc
    plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))    
    all_acc.append(acc)
    all_auc.append(roc_auc)
    i = i+1
    
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6))#, label='Luck')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Decision Tree (Dataset C)')
plt.legend(loc="lower right")
plt.show()

all_acc=np.asarray(all_acc)
all_auc=np.asarray(all_auc)
print(all_acc)
# print 95% C.I. for both accuracy and AUC based on CV
print("Mean Accuracy: %0.3f (+/- %0.3f)" % (all_acc.mean(), all_acc.std() * 1.96))
print(all_auc)
print("Mean AUC: %0.3f (+/- %0.3f)" % (all_auc.mean(), all_auc.std() * 1.96))
# Out:
# Prediction accuracy: 0.914285714286
# Area under ROC curve (AUC): 0.972222222222
# Prediction accuracy: 0.857142857143
# Area under ROC curve (AUC): 0.814516129032
# Prediction accuracy: 0.742857142857
# Area under ROC curve (AUC): 0.842657342657
# Prediction accuracy: 0.828571428571
# Area under ROC curve (AUC): 0.800925925926
# Prediction accuracy: 0.771428571429
# Area under ROC curve (AUC): 0.597701149425
# [ 0.91428571  0.85714286  0.74285714  0.82857143  0.77142857]
# Mean Accuracy: 0.823 (+/- 0.120)
# [ 0.97222222  0.81451613  0.84265734  0.80092593  0.59770115]
# Mean AUC: 0.806 (+/- 0.236)
